# %%
import pandas as pd

# %%
df=pd.read_csv("/content/data.csv")

# %%
df.head()
# Out:
#                   date      price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  2014-05-02 00:00:00   313000.0       3.0       1.50         1340      7912
# 1  2014-05-02 00:00:00  2384000.0       5.0       2.50         3650      9050
# 2  2014-05-02 00:00:00   342000.0       3.0       2.00         1930     11947
# 3  2014-05-02 00:00:00   420000.0       3.0       2.25         2000      8030
# 4  2014-05-02 00:00:00   550000.0       4.0       2.50         1940     10500
#
#    floors  waterfront  view  condition  sqft_above  sqft_basement  yr_built  \
# 0     1.5           0     0          3        1340              0      1955
# 1     2.0           0     4          5        3370            280      1921
# 2     1.0           0     0          4        1930              0      1966
# 3     1.0           0     0          4        1000           1000      1963
# 4     1.0           0     0          4        1140            800      1976
#
# ...

# %%
df.shape
# Out:
# (4600, 18)

# %%
df_waterfront=df[df['waterfront']==1]
print(df_waterfront)
# Out:
#                      date      price  bedrooms  bathrooms  sqft_living  \
# 381   2014-05-08 00:00:00   988500.0       3.0       2.75         2015
# 404   2014-05-09 00:00:00  2400000.0       3.0       2.25         3000
# 478   2014-05-12 00:00:00  1200000.0       3.0       1.75         1560
# 518   2014-05-12 00:00:00   947500.0       3.0       2.75         2980
# 535   2014-05-12 00:00:00   615000.0       2.0       1.75         2040
# 581   2014-05-13 00:00:00  2555000.0       4.0       2.50         5300
# 1163  2014-05-22 00:00:00   503000.0       2.0       1.75         2860
# 1301  2014-05-24 00:00:00  2000000.0       5.0       4.00         4580
# 1464  2014-05-28 00:00:00  1175000.0       3.0       2.50         1970
# 1639  2014-05-30 00:00:00   800000.0       2.0       2.25         1730
# 2031  2014-06-06 00:00:00  1150000.0       3.0       1.50         2170
# 2083  2014-06-08 00:00:00  2700000.0       4.0       3.25         4420
# ...

# %%
df.isnull().sum()
# Out:
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# street           0
# city             0
# statezip         0
# country          0
# dtype: int64

# %%
df_condition=df[df['condition']==5]
print(df_condition)
# Out:
#                      date         price  bedrooms  bathrooms  sqft_living  \
# 1     2014-05-02 00:00:00  2.384000e+06       5.0       2.50         3650
# 11    2014-05-02 00:00:00  1.400000e+06       4.0       2.50         2920
# 20    2014-05-02 00:00:00  7.500000e+05       3.0       1.75         2240
# 27    2014-05-02 00:00:00  6.980000e+05       4.0       2.25         2200
# 38    2014-05-02 00:00:00  4.030000e+05       3.0       2.00         1960
# ...                   ...           ...       ...        ...          ...
# 4557  2014-06-27 00:00:00  4.715000e+05       4.0       3.00         2370
# 4558  2014-06-28 00:00:00  0.000000e+00       4.0       4.25         3500
# 4566  2014-07-01 00:00:00  5.586538e+05       3.0       2.50         1530
# 4576  2014-07-02 00:00:00  2.450000e+05       3.0       3.00         2470
# 4579  2014-07-06 00:00:00  4.547900e+05       2.0       1.75         1990
#
#       sqft_lot  floors  waterfront  view  condition  sqft_above  \
# ...

# %%
df_price=df['price']
df_condition=df[df['condition']==5]
print(df_condition)
# Out:
#                      date         price  bedrooms  bathrooms  sqft_living  \
# 1     2014-05-02 00:00:00  2.384000e+06       5.0       2.50         3650
# 11    2014-05-02 00:00:00  1.400000e+06       4.0       2.50         2920
# 20    2014-05-02 00:00:00  7.500000e+05       3.0       1.75         2240
# 27    2014-05-02 00:00:00  6.980000e+05       4.0       2.25         2200
# 38    2014-05-02 00:00:00  4.030000e+05       3.0       2.00         1960
# ...                   ...           ...       ...        ...          ...
# 4557  2014-06-27 00:00:00  4.715000e+05       4.0       3.00         2370
# 4558  2014-06-28 00:00:00  0.000000e+00       4.0       4.25         3500
# 4566  2014-07-01 00:00:00  5.586538e+05       3.0       2.50         1530
# 4576  2014-07-02 00:00:00  2.450000e+05       3.0       3.00         2470
# 4579  2014-07-06 00:00:00  4.547900e+05       2.0       1.75         1990
#
#       sqft_lot  floors  waterfront  view  condition  sqft_above  \
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
price=df.price.max()
print(price)
price=df.price.min()
print(price)
price=df.price.mean()
print(price)
# Out:
# 26590000.0
# 0.0
# 551962.9884732141

# %%
print(df_price.max())
print(df_price.min())
print(df_price.mean())
# Out:
# 26590000.0
# 0.0
# 551962.9884732141

# %%
plt.pie(df['condition'].value_counts(),labels=df['condition'].unique())
plt.title('condition')
plt.show()

# %%
df['city'].value_counts()
# Out:
# Seattle                1573
# Renton                  293
# Bellevue                286
# Redmond                 235
# Issaquah                187
# Kirkland                187
# Kent                    185
# Auburn                  176
# Sammamish               175
# Federal Way             148
# Shoreline               123
# Woodinville             115
# Maple Valley             96
# Mercer Island            86
# Burien                   74
# Snoqualmie               71
# Kenmore                  66
# Des Moines               58
# North Bend               50
# Covington                43
# Duvall                   42
# Lake Forest Park         36
# Bothell                  33
# Newcastle                33
# SeaTac                   29
# Tukwila                  29
# Vashon                   29
# Enumclaw                 28
# Carnation                22
# Normandy Park            18
# Clyde Hill               11
# Medina                   11
# Fall City                11
# ...

# %%
sns.countplot(x='city',data=df)
plt.xticks(rotation=90)
plt.title('Cities')
# Out:
# Text(0.5, 1.0, 'Cities')

# %%
sns.countplot(x='bedrooms',data=df)
plt.xticks(rotation=90)
plt.title('bedroom')
# Out:
# Text(0.5, 1.0, 'bedroom')

# %%
df.plot(kind='scatter',x='sqft_living',y='price')
plt.show()

# %%
plt.bar(avg.index,avg.values)
plt.xlabel("bedrooms")
plt.ylabel("price")
plt.xticks(rotation=90)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.bar(avg.index,avg.values)
plt.xlabel("city")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
avg=df.groupby('bedrooms')['price'].mean()
print(avg)
# Out:
# bedrooms
# 0.0    1.195324e+06
# 1.0    2.740763e+05
# 2.0    3.916219e+05
# 3.0    4.886130e+05
# 4.0    6.351194e+05
# 5.0    7.701860e+05
# 6.0    8.173628e+05
# 7.0    1.049429e+06
# 8.0    1.155000e+06
# 9.0    5.999990e+05
# Name: price, dtype: float64

# %%
plt.bar(avg.index,avg.values)
plt.xlabel('bedroom')
plt.ylabel('price')
plt.show()

# %%
sns.scatterplot(x='sqft_living',y='price',data=df)
# Out:
# <Axes: xlabel='sqft_living', ylabel='price'>
