# %%
import pandas as pd

# %%
df_skin=pd.read_csv("/content/metadata.csv")

# %%
df_skin.head()
# Out:
#   patient_id  lesion_id  smoke  drink background_father background_mother  \
# 0   PAT_1516       1765    NaN    NaN               NaN               NaN
# 1     PAT_46        881  False  False         POMERANIA         POMERANIA
# 2   PAT_1545       1867    NaN    NaN               NaN               NaN
# 3   PAT_1989       4061    NaN    NaN               NaN               NaN
# 4    PAT_684       1302  False   True         POMERANIA         POMERANIA
#
#    age pesticide  gender skin_cancer_history  ... diameter_2 diagnostic  \
# 0    8       NaN     NaN                 NaN  ...        NaN        NEV
# 1   55     False  FEMALE                True  ...        5.0        BCC
# 2   77       NaN     NaN                 NaN  ...        NaN        ACK
# 3   75       NaN     NaN                 NaN  ...        NaN        ACK
# 4   79     False    MALE                True  ...        5.0        BCC
#
#     itch   grew   hurt  changed  bleed elevation                 img_id  \
# ...

# %%
df_skin.shape
# Out:
# (2298, 26)

# %%
df_skin.describe()
# Out:
#          lesion_id          age  fitspatrick   diameter_1   diameter_2
# count  2298.000000  2298.000000  1494.000000  1494.000000  1494.000000
# mean   1529.933856    60.464752     2.265730    11.897055     8.852209
# std    1196.285644    15.894866     0.729029     8.634492     5.797036
# min       6.000000     6.000000     1.000000     0.000000     0.000000
# 25%     720.500000    52.000000     2.000000     7.000000     5.000000
# 50%    1297.000000    62.000000     2.000000    10.000000     8.000000
# 75%    1782.750000    72.000000     3.000000    15.000000    10.000000
# max    4820.000000    94.000000     6.000000   100.000000    70.000000

# %%
df_skin['lesion_id'].unique()
# Out:
# array([1765,  881, 1867, ...,  934, 3156, 3189])

# %%
df_skin['patient_id'].unique()
# Out:
# array(['PAT_1516', 'PAT_46', 'PAT_1545', ..., 'PAT_491', 'PAT_1343',
#        'PAT_1714'], dtype=object)

# %%
df_skin.isnull().sum()
# Out:
# patient_id               0
# lesion_id                0
# smoke                  804
# drink                  804
# background_father      818
# background_mother      822
# age                      0
# pesticide              804
# gender                 804
# skin_cancer_history    804
# cancer_history         804
# has_piped_water        804
# has_sewage_system      804
# fitspatrick            804
# region                   0
# diameter_1             804
# diameter_2             804
# diagnostic               0
# itch                     0
# grew                     0
# hurt                     0
# changed                  0
# bleed                    0
# elevation                0
# img_id                   0
# biopsed                  0
# dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_skin.plot(kind='scatter',x='age',y='lesion_id')
plt.show()

# %%
avg=df_skin.groupby('gender')['smoke'].mean()
print(avg)
# Out:
# gender
# FEMALE    0.070385
# MALE      0.201080
# Name: smoke, dtype: float64

# %%
plt.bar(avg.index,avg.values)
plt.xlabel("gender")
plt.ylabel("smoke")
plt.xticks(rotation=90)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
df_face=df_skin[df_skin['region']=='FACE']
print(df_face)
# Out:
#      patient_id  lesion_id  smoke  drink background_father background_mother  \
# 2      PAT_1545       1867    NaN    NaN               NaN               NaN
# 6       PAT_778       1471  False   True           GERMANY             ITALY
# 7       PAT_117        179  False  False         POMERANIA         POMERANIA
# 15      PAT_741       1401   True  False         POMERANIA         POMERANIA
# 22     PAT_1653       2916    NaN    NaN               NaN               NaN
# ...         ...        ...    ...    ...               ...               ...
# 2284    PAT_498        944  False   True         POMERANIA         POMERANIA
# 2290   PAT_1294       1031    NaN    NaN               NaN               NaN
# 2291    PAT_273        421  False  False         POMERANIA         POMERANIA
# 2292    PAT_491        934  False  False         POMERANIA         POMERANIA
# 2296    PAT_326        690  False  False         POMERANIA         POMERANIA
#
# ...
