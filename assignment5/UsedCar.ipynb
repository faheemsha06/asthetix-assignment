# %%
import pandas as pd

# %%
df=pd.read_csv("/content/drive/MyDrive/raptor/used_cars_UK.csv")

# %%
df.head()
# Out:
#    Unnamed: 0           title  Price  Mileage(miles)  Registration_Year  \
# 0           0     SKODA Fabia   6900           70189               2016
# 1           1  Vauxhall Corsa   1495           88585               2008
# 2           2     Hyundai i30    949          137000               2011
# 3           3      MINI Hatch   2395           96731               2010
# 4           4  Vauxhall Corsa   1000           85000               2013
#
#    Previous Owners Fuel type  Body type Engine Gearbox  Doors  Seats  \
# 0              3.0    Diesel  Hatchback   1.4L  Manual    5.0    5.0
# 1              4.0    Petrol  Hatchback   1.2L  Manual    3.0    5.0
# 2              NaN    Petrol  Hatchback   1.4L  Manual    5.0    5.0
# 3              5.0    Petrol  Hatchback   1.4L  Manual    3.0    4.0
# 4              NaN    Diesel  Hatchback   1.3L  Manual    5.0    5.0
#
#   Emission Class Service history
# 0         Euro 6             NaN
# 1         Euro 4            Full
# ...

# %%
milegae_and_price=df[(df['Mileage(miles)']>50000) & (df['Price']>5000)]
print(milegae_and_price)
# Out:
#       Unnamed: 0                  title  Price  Mileage(miles)  \
# 0              0            SKODA Fabia   6900           70189
# 12            12            SKODA Fabia   6900           70189
# 13            14           BMW 3 Series  19800           69690
# 21            22     Mercedes-Benz A180  14498           53055
# 25            26  Mercedes-Benz A Class  15900           62402
# ...          ...                    ...    ...             ...
# 3596        4628              SEAT Leon   5495          128000
# 3600        4635              SEAT Leon   5495          128000
# 3625        4664     Vauxhall Astra GTC   7495           50312
# 3638        4678         Nissan Qashqai   7995           67000
# 3681        4724                Audi A4   6990          119000
#
#       Registration_Year  Previous Owners              Fuel type  Body type  \
# 0                  2016              3.0                 Diesel  Hatchback
# ...

# %%
diesel_hatchback=df[(df['Fuel type']=='Diesel') & (df['Body type']=='Hatchback')]
print(diesel_hatchback)
# Out:
#       Unnamed: 0           title  Price  Mileage(miles)  Registration_Year  \
# 0              0     SKODA Fabia   6900           70189               2016
# 4              4  Vauxhall Corsa   1000           85000               2013
# 9              9     Peugeot 207   1299           87000               2008
# 10            10     Ford Fiesta   1495          181693               2009
# 12            12     SKODA Fabia   6900           70189               2016
# ...          ...             ...    ...             ...                ...
# 3654        4695  Vauxhall Corsa   1995          126000               2013
# 3656        4697    Toyota Auris   1295          158469               2008
# 3669        4711  Renault Megane   2489          129000               2013
# 3670        4712       Fiat Idea   1295           84000               2007
# 3678        4721      Citroen C3   1795           85962               2009
#
# ...

# %%
automatic_hatchback=df[(df['Gearbox']=='Automatic') | (df['Body type']=='Hatchback')]
print(automatic_hatchback)
# Out:
#       Unnamed: 0           title  Price  Mileage(miles)  Registration_Year  \
# 0              0     SKODA Fabia   6900           70189               2016
# 1              1  Vauxhall Corsa   1495           88585               2008
# 2              2     Hyundai i30    949          137000               2011
# 3              3      MINI Hatch   2395           96731               2010
# 4              4  Vauxhall Corsa   1000           85000               2013
# ...          ...             ...    ...             ...                ...
# 3677        4720   Honda Prelude   2475          156097               1998
# 3678        4721      Citroen C3   1795           85962               2009
# 3679        4722  Nissan Qashqai   1695          104000               2009
# 3680        4723  Renault Megane   1395           76202               2006
# 3684        4727  Vauxhall Corsa   2000           82160               2013
#
# ...

# %%
count=(df['Registration_Year']>=2015).value_counts()
count
# Out:
# False    2555
# True     1130
# Name: Registration_Year, dtype: int64
