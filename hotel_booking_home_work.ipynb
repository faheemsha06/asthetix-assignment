# %%
import pandas as pd

# %%
df=pd.read_csv("hotel_bookings.csv")

# %%
df.head
# Out:
# <bound method NDFrame.head of               hotel  is_canceled  lead_time  arrival_date_year  \
# 0      Resort Hotel            0        342               2015
# 1      Resort Hotel            0        737               2015
# 2      Resort Hotel            0          7               2015
# 3      Resort Hotel            0         13               2015
# 4      Resort Hotel            0         14               2015
# ...             ...          ...        ...                ...
# 29259  Resort Hotel            0        386               2016
# 29260  Resort Hotel            0         77               2016
# 29261  Resort Hotel            0        134               2016
# 29262  Resort Hotel            0        220               2016
# 29263  Resort Hotel            0        189               2016
#
#       arrival_date_month  arrival_date_week_number  arrival_date_day_of_month  \
# 0                   July                        27                          1
# ...

# %%
df.tail
# Out:
# <bound method NDFrame.tail of               hotel  is_canceled  lead_time  arrival_date_year  \
# 0      Resort Hotel            0        342               2015
# 1      Resort Hotel            0        737               2015
# 2      Resort Hotel            0          7               2015
# 3      Resort Hotel            0         13               2015
# 4      Resort Hotel            0         14               2015
# ...             ...          ...        ...                ...
# 29259  Resort Hotel            0        386               2016
# 29260  Resort Hotel            0         77               2016
# 29261  Resort Hotel            0        134               2016
# 29262  Resort Hotel            0        220               2016
# 29263  Resort Hotel            0        189               2016
#
#       arrival_date_month  arrival_date_week_number  arrival_date_day_of_month  \
# 0                   July                        27                          1
# ...

# %%
df['arrival_date_day_of_month'].dtype
# Out:
# dtype('int64')

# %%
df.dtypes
# Out:
# hotel                              object
# is_canceled                         int64
# lead_time                           int64
# arrival_date_year                   int64
# arrival_date_month                 object
# arrival_date_week_number            int64
# arrival_date_day_of_month           int64
# stays_in_weekend_nights             int64
# stays_in_week_nights                int64
# adults                              int64
# children                            int64
# babies                              int64
# meal                               object
# country                            object
# market_segment                     object
# distribution_channel               object
# is_repeated_guest                   int64
# previous_cancellations              int64
# previous_bookings_not_canceled      int64
# reserved_room_type                 object
# assigned_room_type                 object
# booking_changes                     int64
# ...

# %%
df.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'company', 'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date'],
#       dtype='object')

# %%
df.shape
# Out:
# (29264, 32)

# %%
df['arrival_date_day_of_month'].mean()
# Out:
# 15.723141060688901

# %%
df.groupby('arrival_date_day_of_month')[['lead_time']].mean()
# Out:
#                             lead_time
# arrival_date_day_of_month
# 1                          111.317943
# 2                          104.389728
# 3                          110.469450
# 4                           98.218238
# 5                           87.209410
# 6                          112.990077
# 7                           85.207464
# 8                          107.348131
# 9                           90.241080
# 10                          97.016374
# 11                          81.450526
# 12                         136.045814
# 13                          84.680990
# 14                         100.302217
# 15                         120.254764
# 16                          88.478049
# 17                         100.276342
# 18                          79.621963
# 19                          85.580844
# 20                         112.714602
# 21                         112.241989
# 22                          93.908120
# 23                          73.171393
# ...

# %%
df_sub=df[df['lead_time']>10]
print(df_sub)
# Out:
#               hotel  is_canceled  lead_time  arrival_date_year  \
# 0      Resort Hotel            0        342               2015
# 1      Resort Hotel            0        737               2015
# 3      Resort Hotel            0         13               2015
# 4      Resort Hotel            0         14               2015
# 5      Resort Hotel            0         14               2015
# ...             ...          ...        ...                ...
# 29259  Resort Hotel            0        386               2016
# 29260  Resort Hotel            0         77               2016
# 29261  Resort Hotel            0        134               2016
# 29262  Resort Hotel            0        220               2016
# 29263  Resort Hotel            0        189               2016
#
#       arrival_date_month  arrival_date_week_number  arrival_date_day_of_month  \
# 0                   July                        27                          1
# ...

# %%
df[['is_canceled','adults']]
# Out:
#        is_canceled  adults
# 0                0       2
# 1                0       2
# 2                0       1
# 3                0       1
# 4                0       2
# ...            ...     ...
# 29259            0       2
# 29260            0       2
# 29261            0       2
# 29262            0       2
# 29263            0       3
#
# [29264 rows x 2 columns]

# %%
df[10:20]
# Out:
#            hotel  is_canceled  lead_time  arrival_date_year  \
# 10  Resort Hotel            1         23               2015
# 11  Resort Hotel            0         35               2015
# 12  Resort Hotel            0         68               2015
# 13  Resort Hotel            0         18               2015
# 14  Resort Hotel            0         37               2015
# 15  Resort Hotel            0         68               2015
# 16  Resort Hotel            0         37               2015
# 17  Resort Hotel            0         12               2015
# 18  Resort Hotel            0          0               2015
# 19  Resort Hotel            0          7               2015
#
#    arrival_date_month  arrival_date_week_number  arrival_date_day_of_month  \
# 10               July                        27                          1
# 11               July                        27                          1
# 12               July                        27                          1
# ...

# %%
df_sub.shape
# Out:
# (22496, 32)

# %%
df.iloc[0]
# Out:
# hotel                             Resort Hotel
# is_canceled                                  0
# lead_time                                  342
# arrival_date_year                         2015
# arrival_date_month                        July
# arrival_date_week_number                    27
# arrival_date_day_of_month                    1
# stays_in_weekend_nights                      0
# stays_in_week_nights                         0
# adults                                       2
# children                                     0
# babies                                       0
# meal                                        BB
# country                                    PRT
# market_segment                          Direct
# distribution_channel                    Direct
# is_repeated_guest                            0
# previous_cancellations                       0
# previous_bookings_not_canceled               0
# reserved_room_type                           C
# ...

# %%
df.iloc[-1]
# Out:
# hotel                             Resort Hotel
# is_canceled                                  0
# lead_time                                  189
# arrival_date_year                         2016
# arrival_date_month                     October
# arrival_date_week_number                    43
# arrival_date_day_of_month                   21
# stays_in_weekend_nights                      1
# stays_in_week_nights                         2
# adults                                       3
# children                                     0
# babies                                       0
# meal                                        BB
# country                                    IRL
# market_segment                       Online TA
# distribution_channel                     TA/TO
# is_repeated_guest                            0
# previous_cancellations                       0
# previous_bookings_not_canceled               0
# reserved_room_type                           D
# ...

# %%
df.iloc[:,0]
# Out:
# 0        Resort Hotel
# 1        Resort Hotel
# 2        Resort Hotel
# 3        Resort Hotel
# 4        Resort Hotel
#              ...
# 29259    Resort Hotel
# 29260    Resort Hotel
# 29261    Resort Hotel
# 29262    Resort Hotel
# 29263    Resort Hotel
# Name: hotel, Length: 29264, dtype: object

# %%
df.iloc[0:7]
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
# 5  Resort Hotel            0         14               2015               July
# 6  Resort Hotel            0          0               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
# ...

# %%
df_sorted=df.sort_values(by='arrival_date_year')
df_sorted.head()
# Out:
#               hotel  is_canceled  lead_time  arrival_date_year  \
# 0      Resort Hotel            0        342               2015
# 14742  Resort Hotel            1        259               2015
# 14741  Resort Hotel            1        259               2015
# 14740  Resort Hotel            1        259               2015
# 14739  Resort Hotel            1        259               2015
#
#       arrival_date_month  arrival_date_week_number  arrival_date_day_of_month  \
# 0                   July                        27                          1
# 14742          September                        38                         17
# 14741          September                        38                         17
# 14740          September                        38                         17
# 14739          September                        38                         17
#
#        stays_in_weekend_nights  stays_in_week_nights  adults  ...  \
# ...

# %%
df_sorted.sort_values(by=['arrival_date_year','lead_time'],ascending=[True,False])
df_sorted.head()
# Out:
#               hotel  is_canceled  lead_time  arrival_date_year  \
# 0      Resort Hotel            0        342               2015
# 14742  Resort Hotel            1        259               2015
# 14741  Resort Hotel            1        259               2015
# 14740  Resort Hotel            1        259               2015
# 14739  Resort Hotel            1        259               2015
#
#       arrival_date_month  arrival_date_week_number  arrival_date_day_of_month  \
# 0                   July                        27                          1
# 14742          September                        38                         17
# 14741          September                        38                         17
# 14740          September                        38                         17
# 14739          September                        38                         17
#
#        stays_in_weekend_nights  stays_in_week_nights  adults  ...  \
# ...
